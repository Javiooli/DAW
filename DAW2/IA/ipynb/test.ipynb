# %% [markdown]
# **Això és un test**
#
# *Això és un altre*
#
# I aquest és l'últim

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import Perceptron # type: ignore
from sklearn.metrics import accuracy_score # type: ignore
from sklearn.inspection import DecisionBoundaryDisplay # type: ignore

# %%
# !wget https://archive.ics.uci.edu/static/public/53/iris.zip
# !unzip iris.zip
# Out:
# --2025-12-15 20:01:12--  https://archive.ics.uci.edu/static/public/53/iris.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘iris.zip’
#
# iris.zip                [ <=>                ]   3.65K  --.-KB/s    in 0s
#
# 2025-12-15 20:01:13 (1.46 GB/s) - ‘iris.zip’ saved [3738]
#
# Archive:  iris.zip
#   inflating: Index
#   inflating: bezdekIris.data
#   inflating: iris.data
#   inflating: iris.names
