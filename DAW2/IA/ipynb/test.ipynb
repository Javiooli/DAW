# %% [markdown]
# Això és un test

# %%
primo = "sabe o no sabe"

# %%
print(f"Hello World!, {primo}")
# Out:
# Running cells with 'venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/javiooli/Documents/GitHub/DAW/DAW2/IA/ipynb/venv/bin/python -m pip install ipykernel -U --force-reinstall'
